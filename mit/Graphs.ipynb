# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
from collections import namedtuple


n_groups = 3

# means_men = (20, 35, 30, 35, 27)
slices=(18.31,17.02,5.83)
lut=(11.33,11.20,4.21)
bram=(10.36,7.14,3.57)
dsp=(24.54,21.81,10.90)
ff=(6.56,6.08,2.22)
fig, ax = plt.subplots()

index = np.arange(n_groups)
bar_width = 0.08

# opacity = 0.4
error_config = {'ecolor': '0.3'}

rects1 = ax.bar(index+bar_width, slices, bar_width, color='magenta', error_kw=error_config,label='Slices')
rects2 = ax.bar(index + 2*bar_width, lut , bar_width, color='aqua', error_kw=error_config, label='LUTs')
rects4 = ax.bar(index + 3*bar_width, bram , bar_width, color='gold', error_kw=error_config, label='BRAM')
rects5 = ax.bar(index + 0*bar_width, dsp , bar_width, color='lawngreen', error_kw=error_config, label='DSPs')
rects3 = ax.bar(index + 4*bar_width, ff , bar_width, color='red', error_kw=error_config, label='FF')
ax.set_xlabel('Precision <Address,TimeStamp,Weights> in bits',fontsize=14,fontweight='bold')
ax.set_ylabel('% Resource Utilisation',fontsize=14,fontweight='bold')
# ax.set_title('')
ax.set_xticks(index + bar_width / 2)
ax.set_xticklabels(('<32,32,32>', '<10,18,32>', '<10,2,fixed(24,12)>'))
ax.legend(fontsize=12)
ax2 = ax.twinx()   # mirror them
ax2.plot([10.04,10.04,3.14],marker='o',color='blue',label='Latency')
ax2.set_ylabel('Latency in ms',fontsize=12,fontweight='bold')
ax2.legend(loc='center right',fontsize=12)
fig.tight_layout()
plt.rc('xtick', labelsize=16)    # fontsize of the tick labels
plt.rc('ytick', labelsize=16)
plt.savefig('resource.png', bbox_inches = 'tight')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
from collections import namedtuple


n_groups = 4
fig, ax = plt.subplots(figsize=(4,4))

index = np.arange(n_groups)
bar_width = 0.1

# opacity = 0.4
error_config = {'ecolor': '0.3'}
slices=(24.06505798,
4.84217589,
10.60501481,
5.948690592)
rects1 = ax.bar(index+bar_width, slices, bar_width, color='darkgrey', error_kw=error_config)
# rects2 = ax.bar(index + 2*bar_width, lut , bar_width, color='aqua', error_kw=error_config, label='LUTs')
# rects4 = ax.bar(index + 3*bar_width, bram , bar_width, color='gold', error_kw=error_config, label='BRAM')
# rects5 = ax.bar(index + 0*bar_width, dsp , bar_width, color='lawngreen', error_kw=error_config, label='DSPs')
# rects3 = ax.bar(index + 4*bar_width, ff , bar_width, color='red', error_kw=error_config, label='FF')
# ax.set_xlabel('Precision <Address,TimeStamp,Weights> in bits',fontsize=14,fontweight='bold')
ax.set_ylabel('% Vertices for 90% Edges',fontsize=14,fontweight='bold')
# ax.set_title('')
ax.set_xticks(index + bar_width )
# ax.set_xticklabels(('<32,32,32>', '<10,18,32>', '<10,2,fixed(24,12)>'))
ax.set_xticklabels(('amazon', 'wiki', 'pokec','ljournal'))
ax.legend(fontsize=12)
# ax2 = ax.twinx()   # mirror them
# ax2.plot([10.04,10.04,3.14],marker='o',color='blue',label='Latency')
# ax2.set_ylabel('Latency in ms',fontsize=12,fontweight='bold')
# ax2.legend(loc='center right',fontsize=12)
fig.tight_layout()
plt.rc('xtick', labelsize=16)    # fontsize of the tick labels
plt.rc('ytick', labelsize=16)
plt.savefig('power.png', bbox_inches = 'tight')
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
from collections import namedtuple
import matplotlib as mpl
# mpl.rcParams['text.usetex'] = False?
# mpl.rcParams['text.latex.preamble'] = [r'\usepackage{amsmath}']

n_groups = 4

fig, ax = plt.subplots()
# our=(49.55676144,683.4615698,297.9676353,10.71814563)
# gram=(263.9169063,11.29993975,217.6476789,16.90999926)
our=(35256993.89,63334187122,81031685.27,266495422.9)
gram=(187762809.4,1047129100,59188838.4,420449353.6)
graphr=(711446.69,92666786.14,271947.9422,24863948.67)
index = np.arange(n_groups)
print(index)
bar_width = 0.08
ax.set_yscale('log')
# opacity = 0.4
error_config = {'ecolor': '0.3'}

rects1 = ax.bar(index+bar_width, our, bar_width, color='magenta', error_kw=error_config,label='Ours')
rects2 = ax.bar(index + 2*bar_width, gram , bar_width, color='aqua', error_kw=error_config, label='GRAM')
rects4 = ax.bar(index + 3*bar_width, graphr , bar_width, color='gold', error_kw=error_config, label='GraphR')
# rects5 = ax.bar(index + 0*bar_width, dsp , bar_width, color='lawngreen', error_kw=error_config, label='DSPs')
# rects3 = ax.bar(index + 4*bar_width, ff , bar_width, color='red', error_kw=error_config, label='FF')
# ax.set_xlabel('Precision <Address,TimeStamp,Weights> in bits',fontsize=14,fontweight='bold')
ax.set_ylabel('ED^2P (GraphMat=1)',fontsize=14,fontweight='bold')
# ax.set_title('')
ax.set_xticks(index + bar_width / 2)
ax.set_xticklabels(('amazon', 'wiki', 'pokec','ljournal'))
ax.legend(fontsize=12)
# ax2 = ax.twinx()   # mirror them
# ax2.plot([10.04,10.04,3.14],marker='o',color='blue',label='Latency')
# ax2.set_ylabel('Latency in ms',fontsize=12,fontweight='bold')
# ax2.legend(loc='center right',fontsize=12)
fig.tight_layout()
plt.rc('xtick', labelsize=16)    # fontsize of the tick labels
plt.rc('ytick', labelsize=16)
plt.savefig('edpbfs.png', bbox_inches = 'tight')
plt.show()
# Out:
# [0 1 2 3]

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
from collections import namedtuple
import matplotlib as mpl
# mpl.rcParams['text.usetex'] = False?
# mpl.rcParams['text.latex.preamble'] = [r'\usepackage{amsmath}']

n_groups = 4

fig, ax = plt.subplots()
our=(18623207.71,32448930722,37064537.63,137199056.3)
gram=(43739662.5,15761458.52,54902165.15,50055837.3)
graphr=(341934.974,2504484.765,85838.0575,376718.1153)
index = np.arange(n_groups)
print(index)
bar_width = 0.08
ax.set_yscale('log')
# opacity = 0.4
error_config = {'ecolor': '0.3'}

rects1 = ax.bar(index+bar_width, our, bar_width, color='magenta', error_kw=error_config,label='Ours')
rects2 = ax.bar(index + 2*bar_width, gram , bar_width, color='aqua', error_kw=error_config, label='GRAM')
rects4 = ax.bar(index + 3*bar_width, graphr , bar_width, color='gold', error_kw=error_config, label='GraphR')
# rects5 = ax.bar(index + 0*bar_width, dsp , bar_width, color='lawngreen', error_kw=error_config, label='DSPs')
# rects3 = ax.bar(index + 4*bar_width, ff , bar_width, color='red', error_kw=error_config, label='FF')
# ax.set_xlabel('Precision <Address,TimeStamp,Weights> in bits',fontsize=14,fontweight='bold')
ax.set_ylabel('ED^2P (GraphMat=1)',fontsize=14,fontweight='bold')
# ax.set_title('')
ax.set_xticks(index + bar_width / 2)
ax.set_xticklabels(('amazon', 'wiki', 'pokec','ljournal'))
ax.legend(fontsize=12)
# ax2 = ax.twinx()   # mirror them
# ax2.plot([10.04,10.04,3.14],marker='o',color='blue',label='Latency')
# ax2.set_ylabel('Latency in ms',fontsize=12,fontweight='bold')
# ax2.legend(loc='center right',fontsize=12)
fig.tight_layout()
plt.rc('xtick', labelsize=16)    # fontsize of the tick labels
plt.rc('ytick', labelsize=16)
plt.savefig('edpsssp.png', bbox_inches = 'tight')
plt.show()
# Out:
# [0 1 2 3]

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
from collections import namedtuple
import matplotlib as mpl
# mpl.rcParams['text.usetex'] = False?
# mpl.rcParams['text.latex.preamble'] = [r'\usepackage{amsmath}']

n_groups = 4

fig, ax = plt.subplots()
# our=(49.55676144,683.4615698,297.9676353,10.71814563)
# gram=(263.9169063,11.29993975,217.6476789,16.90999926)
graphr=(48526.1304,6268.99,3062.5,24606.4)
gram=(8630.88417,75681.39375,52778.047,75681.39375)
our=(104344.2196,1988348.89
,3575369.597,
10180040.88)
index = np.arange(n_groups)
print(index)
bar_width = 0.08
ax.set_yscale('log')
# opacity = 0.4
error_config = {'ecolor': '0.3'}

rects1 = ax.bar(index+bar_width, our, bar_width, color='magenta', error_kw=error_config,label='Ours')
rects2 = ax.bar(index + 2*bar_width, gram , bar_width, color='aqua', error_kw=error_config, label='GRAM')
rects4 = ax.bar(index + 3*bar_width, graphr , bar_width, color='gold', error_kw=error_config, label='GraphR')
# rects5 = ax.bar(index + 0*bar_width, dsp , bar_width, color='lawngreen', error_kw=error_config, label='DSPs')
# rects3 = ax.bar(index + 4*bar_width, ff , bar_width, color='red', error_kw=error_config, label='FF')
# ax.set_xlabel('Precision <Address,TimeStamp,Weights> in bits',fontsize=14,fontweight='bold')
ax.set_ylabel('ED^2P (GraphMat=1)',fontsize=14,fontweight='bold')
# ax.set_title('')
ax.set_xticks(index + bar_width / 2)
ax.set_xticklabels(('amazon', 'wiki', 'pokec','ljournal'))
ax.legend(fontsize=12)
# ax2 = ax.twinx()   # mirror them
# ax2.plot([10.04,10.04,3.14],marker='o',color='blue',label='Latency')
# ax2.set_ylabel('Latency in ms',fontsize=12,fontweight='bold')
# ax2.legend(loc='center right',fontsize=12)
fig.tight_layout()
plt.rc('xtick', labelsize=16)    # fontsize of the tick labels
plt.rc('ytick', labelsize=16)
plt.savefig('edppr.png', bbox_inches = 'tight')
plt.show()
# Out:
# [0 1 2 3]

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
from collections import namedtuple
import matplotlib as mpl
# mpl.rcParams['text.usetex'] = False?
# mpl.rcParams['text.latex.preamble'] = [r'\usepackage{amsmath}']

n_groups = 4

fig, ax = plt.subplots()
our=(148.388298
,3349.080332,371.096142,686.8484397)
gram=(237.1,
290,
230.4,
354.8)
graphr=(34.55,
185.88,
41.24,
185.87)
index = np.arange(n_groups)
print(index)
bar_width = 0.08
ax.set_yscale('log')
# opacity = 0.4
error_config = {'ecolor': '0.3'}

rects1 = ax.bar(index+bar_width, our, bar_width, color='magenta', error_kw=error_config,label='Ours')
rects2 = ax.bar(index + 2*bar_width, gram , bar_width, color='aqua', error_kw=error_config, label='GRAM')
rects4 = ax.bar(index + 3*bar_width, graphr , bar_width, color='gold', error_kw=error_config, label='GraphR')
# rects5 = ax.bar(index + 0*bar_width, dsp , bar_width, color='lawngreen', error_kw=error_config, label='DSPs')
# rects3 = ax.bar(index + 4*bar_width, ff , bar_width, color='red', error_kw=error_config, label='FF')
# ax.set_xlabel('Precision <Address,TimeStamp,Weights> in bits',fontsize=14,fontweight='bold')
ax.set_ylabel('SpeedUp (GraphMat=1)',fontsize=14,fontweight='bold')
# ax.set_title('')
ax.set_xticks(index + bar_width / 2)
ax.set_xticklabels(('amazon', 'wiki', 'pokec','ljournal'))
ax.legend(fontsize=12)
# ax2 = ax.twinx()   # mirror them
# ax2.plot([10.04,10.04,3.14],marker='o',color='blue',label='Latency')
# ax2.set_ylabel('Latency in ms',fontsize=12,fontweight='bold')
# ax2.legend(loc='center right',fontsize=12)
fig.tight_layout()
plt.rc('xtick', labelsize=16)    # fontsize of the tick labels
plt.rc('ytick', labelsize=16)
plt.savefig('sbfs.png', bbox_inches = 'tight')
plt.show()
# Out:
# [0 1 2 3]

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
from collections import namedtuple
import matplotlib as mpl
# mpl.rcParams['text.usetex'] = False?
# mpl.rcParams['text.latex.preamble'] = [r'\usepackage{amsmath}']

n_groups = 4

fig, ax = plt.subplots()
our=(112.980067,
2547.382315,
271.6990764,
525.4631502)
gram=(142.5,
76.66,
221.9,
170.1)
graphr=(28.9,
53.7,
22.1,
28.94)
index = np.arange(n_groups)
print(index)
bar_width = 0.08
ax.set_yscale('log')
# opacity = 0.4
error_config = {'ecolor': '0.3'}

rects1 = ax.bar(index+bar_width, our, bar_width, color='magenta', error_kw=error_config,label='Ours')
rects2 = ax.bar(index + 2*bar_width, gram , bar_width, color='aqua', error_kw=error_config, label='GRAM')
rects4 = ax.bar(index + 3*bar_width, graphr , bar_width, color='gold', error_kw=error_config, label='GraphR')
# rects5 = ax.bar(index + 0*bar_width, dsp , bar_width, color='lawngreen', error_kw=error_config, label='DSPs')
# rects3 = ax.bar(index + 4*bar_width, ff , bar_width, color='red', error_kw=error_config, label='FF')
# ax.set_xlabel('Precision <Address,TimeStamp,Weights> in bits',fontsize=14,fontweight='bold')
ax.set_ylabel('SpeedUp (GraphMat=1)',fontsize=14,fontweight='bold')
# ax.set_title('')
ax.set_xticks(index + bar_width / 2)
ax.set_xticklabels(('amazon', 'wiki', 'pokec','ljournal'))
ax.legend(fontsize=12)
# ax2 = ax.twinx()   # mirror them
# ax2.plot([10.04,10.04,3.14],marker='o',color='blue',label='Latency')
# ax2.set_ylabel('Latency in ms',fontsize=12,fontweight='bold')
# ax2.legend(loc='center right',fontsize=12)
fig.tight_layout()
plt.rc('xtick', labelsize=16)    # fontsize of the tick labels
plt.rc('ytick', labelsize=16)
plt.savefig('speedsssp.png', bbox_inches = 'tight')
plt.show()
# Out:
# [0 1 2 3]

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
from collections import namedtuple
import matplotlib as mpl
# mpl.rcParams['text.usetex'] = False?
# mpl.rcParams['text.latex.preamble'] = [r'\usepackage{amsmath}']

n_groups = 4

fig, ax = plt.subplots()
our=(19.2467368,
96.86581351,
120.185551,
214.1720318)
gram=(5.37,
14.25,
11.9,
14.25)
graphr=(24.2,
8.3,
7,
13)
index = np.arange(n_groups)
print(index)
bar_width = 0.08
ax.set_yscale('log')
# opacity = 0.4
error_config = {'ecolor': '0.3'}

rects1 = ax.bar(index+bar_width, our, bar_width, color='magenta', error_kw=error_config,label='Ours')
rects2 = ax.bar(index + 2*bar_width, gram , bar_width, color='aqua', error_kw=error_config, label='GRAM')
rects4 = ax.bar(index + 3*bar_width, graphr , bar_width, color='gold', error_kw=error_config, label='GraphR')
# rects5 = ax.bar(index + 0*bar_width, dsp , bar_width, color='lawngreen', error_kw=error_config, label='DSPs')
# rects3 = ax.bar(index + 4*bar_width, ff , bar_width, color='red', error_kw=error_config, label='FF')
# ax.set_xlabel('Precision <Address,TimeStamp,Weights> in bits',fontsize=14,fontweight='bold')
ax.set_ylabel('SpeedUp (GraphMat=1)',fontsize=14,fontweight='bold')
# ax.set_title('')
ax.set_xticks(index + bar_width / 2)
ax.set_xticklabels(('amazon', 'wiki', 'pokec','ljournal'))
ax.legend(fontsize=12)
# ax2 = ax.twinx()   # mirror them
# ax2.plot([10.04,10.04,3.14],marker='o',color='blue',label='Latency')
# ax2.set_ylabel('Latency in ms',fontsize=12,fontweight='bold')
# ax2.legend(loc='center right',fontsize=12)
fig.tight_layout()
plt.rc('xtick', labelsize=16)    # fontsize of the tick labels
plt.rc('ytick', labelsize=16)
plt.savefig('speedpr.png', bbox_inches = 'tight')
plt.show()
# Out:
# [0 1 2 3]

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
from collections import namedtuple
import matplotlib as mpl
# mpl.rcParams['text.usetex'] = False?
# mpl.rcParams['text.latex.preamble'] = [r'\usepackage{amsmath}']

n_groups = 4

fig, ax = plt.subplots()
naive=(11.61168384,
31.18468492,
32.17528483,
48.07945362)
poweraware=(3.3989,
4.4017,
4.4125,
5.6123)
index = np.arange(n_groups)
print(index)
bar_width = 0.08
ax.set_yscale('linear')
# opacity = 0.4
error_config = {'ecolor': '0.3'}

rects1 = ax.bar(index+bar_width, naive, bar_width, color='darkgreen', error_kw=error_config,label='Naive')
rects2 = ax.bar(index + 2*bar_width, poweraware , bar_width, color='blue', error_kw=error_config, label='Power-Aware')
# rects4 = ax.bar(index + 3*bar_width, graphr , bar_width, color='gold', error_kw=error_config, label='GraphR')
# rects5 = ax.bar(index + 0*bar_width, dsp , bar_width, color='lawngreen', error_kw=error_config, label='DSPs')
# rects3 = ax.bar(index + 4*bar_width, ff , bar_width, color='red', error_kw=error_config, label='FF')
# ax.set_xlabel('Precision <Address,TimeStamp,Weights> in bits',fontsize=14,fontweight='bold')
ax.set_ylabel('Avg. Hop Count',fontsize=14,fontweight='bold')
# ax.set_title('')
ax.set_xticks(index + bar_width / 2)
ax.set_xticklabels(('amazon', 'wiki', 'pokec','ljournal'))
ax.legend(fontsize=12)
# ax2 = ax.twinx()   # mirror them
# ax2.plot([10.04,10.04,3.14],marker='o',color='blue',label='Latency')
# ax2.set_ylabel('Latency in ms',fontsize=12,fontweight='bold')
# ax2.legend(loc='center right',fontsize=12)
fig.tight_layout()
plt.rc('xtick', labelsize=16)    # fontsize of the tick labels
plt.rc('ytick', labelsize=16)
plt.savefig('hops.png', bbox_inches = 'tight')
plt.show()
# Out:
# [0 1 2 3]

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
from collections import namedtuple
import matplotlib as mpl
# mpl.rcParams['text.usetex'] = False?
# mpl.rcParams['text.latex.preamble'] = [r'\usepackage{amsmath}']

n_groups = 4

fig, ax = plt.subplots(figsize=(6,6))
index = np.arange(n_groups)
print(index)
bar_width = 0.05
ax.set_yscale('linear')
# opacity = 0.4
error_config = {'ecolor': '0.3'}
bfs=np.array((0.6973064389,0.6534137647
,0.640163992,0.634784994)) 
bfs1=(0.4867245731,
0.5940055302,
0.5872613132,
0.579132175)
ssp2=bfs2=np.array((0.03969567899,
0.02094439916,
0.01777341919,
0.02342033099))
sssp=np.array((1.040272139,
0.9947649774,0.9539776642,
0.9710793158))
sssp1=(0.488786815,
0.6013640739,
0.5956316642,
0.5861963446)
pr=np.array(((51.31441975,51.75744392 ,42.18259198, 49.06937054),(51.40860898,
51.690, 42.21803033, 46.75731155),(0.03969567899,0.02094439916, 0.01777341919, 0.02342033099)))
# print(pr[0]+pr[1])
print(bfs+bfs2)
# print(pr[0])
index = np.arange(n_groups)
# print(index)
bar_width = 0.1
ax.set_yscale('log')
opacity = 0.1
error_config = {'ecolor': '0.3'}
#
rects1 = ax.bar(index+bar_width, bfs2, bar_width, color='red', error_kw=error_config,label='Apply')+ax.bar(index+bar_width, bfs, bar_width, bottom=bfs2, color='gold', error_kw=error_config,label='Process')+ax.bar(index+bar_width, bfs1, bar_width,bottom=bfs+bfs2,color='aqua', error_kw=error_config,label='Reduce')
rects1 = ax.bar(index+bar_width, bfs, bar_width, color='none', error_kw=error_config,label='BFS',hatch='o')+ax.bar(index+bar_width, bfs1, bar_width,bottom=bfs ,color='none', error_kw=error_config,hatch='o')
rects2 = ax.bar(index + 2.2*bar_width, sssp2 , bar_width, color='red', error_kw=error_config)+ax.bar(index + 2.2*bar_width, sssp , bar_width,bottom=ssp2, color='gold', error_kw=error_config)+ax.bar(index+2.2*bar_width, sssp1, bar_width,bottom=sssp+ssp2 ,color='aqua', error_kw=error_config)
rects2 = ax.bar(index + 2.2*bar_width, sssp , bar_width, color='none',hatch='x', error_kw=error_config,label='SSSP')+ax.bar(index+2.2*bar_width, sssp2, bar_width,bottom=sssp ,color='none',hatch='x', error_kw=error_config)
rects3 = ax.bar(index + 3.4*bar_width, pr[2] , bar_width, color='red',hatch='/',error_kw=error_config)+ax.bar(index + 3.4*bar_width, pr[0] , bar_width, bottom=pr[2], color='gold',hatch='/',error_kw=error_config)+ax.bar(index+3.4*bar_width, pr[1], bar_width,bottom=pr[0]+pr[2] ,color='aqua', error_kw=error_config)
rects3 = ax.bar(index + 3.4*bar_width, pr[0] , bar_width, color='none',hatch='/',error_kw=error_config,label='PageRank')+ax.bar(index+3.4*bar_width, pr[1], bar_width,bottom=pr[0] ,hatch='/',color='none', error_kw=error_config)

# ax.set_ylabel('SpeedUp (GraphMat=1)',fontsize=14,fontweight='bold')
ax.set_xticks(index + bar_width*2)
ax.set_xticklabels(('amazon', 'wiki', 'pokec','ljournal'))
ax.set_ylabel('Normalized Data Movement w/ Size of Graph',fontsize=14,fontweight='bold')
ax.legend(fontsize=12)
ax.set_ylim( (pow(10,-2),pow(10,3)))
fig.tight_layout()
plt.rc('xtick', labelsize=16)    # fontsize of the tick labels
plt.rc('ytick', labelsize=16)
plt.savefig('data.png', bbox_inches = 'tight')
plt.show()
# Out:
# [0 1 2 3]
# [0.73700212 0.67435816 0.65793741 0.65820532]
